# %%
#!/usr/bin/env python3
import torch
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader, TensorDataset
import argparse
import random

# %%
def load_triples(path):
    triples = []
    with open(path, 'r') as f:
        for line in f:
            h, r, t = line.strip().split()[:3]
            triples.append((h, r, t))
    return triples


class DistMultModel(torch.nn.Module):
    def __init__(self, num_entities, num_relations, embedding_dim):
        super().__init__()
        self.entity_emb = torch.nn.Embedding(num_entities, embedding_dim)
        self.rel_emb = torch.nn.Embedding(num_relations, embedding_dim)
        torch.nn.init.xavier_uniform_(self.entity_emb.weight)
        torch.nn.init.xavier_uniform_(self.rel_emb.weight)

    def forward(self, h, r, t):
        # Score: <e_h, R_r, e_t>
        return (self.entity_emb(h) * self.rel_emb(r) * self.entity_emb(t)).sum(dim=-1)


def negative_sampling(batch, num_entities):
    # Corrupt head or tail at random
    neg = batch.clone()
    mask = torch.rand(batch.size(0), device=batch.device) < 0.5
    # corrupt head
    num_h = mask.sum().item()
    neg[mask, 0] = torch.randint(0, num_entities, (num_h,), device=batch.device)
    # corrupt tail
    num_t = (~mask).sum().item()
    neg[~mask, 2] = torch.randint(0, num_entities, (num_t,), device=batch.device)
    return neg


def train_epoch(model, optimizer, dataloader, num_entities, device):
    model.train()
    total_loss = 0
    dataset_size = 0
    for batch_tuple in dataloader:
        batch = batch_tuple[0].to(device)
        dataset_size += batch.size(0)
        pos = batch
        neg = negative_sampling(pos, num_entities)

        pos_score = model(pos[:, 0], pos[:, 1], pos[:, 2])
        neg_score = model(neg[:, 0], neg[:, 1], neg[:, 2])

        loss = - (F.logsigmoid(pos_score).mean() + F.logsigmoid(-neg_score).mean())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * batch.size(0)

    return total_loss / dataset_size


@torch.no_grad()
def evaluate_loss(model, dataloader, device):
    model.eval()
    total_loss = 0

    for batch_tuple in dataloader:
        batch = batch_tuple[0].to(device)
        score = model(batch[:, 0], batch[:, 1], batch[:, 2])
        loss = -F.logsigmoid(score).mean()
        total_loss += loss.item() * batch.size(0)

    return total_loss / len(dataloader.dataset)


@torch.no_grad()
def evaluate_ranking(model, data_tensor, num_entities, device, num_neg=100, k_values=(1,3,10)):
    """
    Approximate ranking evaluation: for each positive triple, sample num_neg negatives,
    compute rank of the positive, then aggregate MRR and Hits@k.
    """
    model.eval()
    ranks = []
    for triple in data_tensor:
        h, r, t = triple
        h, r, t = h.to(device), r.to(device), t.to(device)
        pos_score = model(h.unsqueeze(0), r.unsqueeze(0), t.unsqueeze(0))

        # generate negatives
        neg_h = torch.randint(0, num_entities, (num_neg,), device=device)
        neg_t = torch.randint(0, num_entities, (num_neg,), device=device)
        mask = torch.rand(num_neg, device=device) < 0.5
        heads = torch.where(mask, neg_h, h.expand(num_neg))
        tails = torch.where(~mask, neg_t, t.expand(num_neg))
        rels = r.expand(num_neg)
        neg_score = model(heads, rels, tails)

        scores = torch.cat([pos_score, neg_score])
        # higher score is better
        ranks_i = torch.argsort(scores, descending=True)
        rank = (ranks_i == 0).nonzero(as_tuple=False).item() + 1
        ranks.append(rank)

    ranks = torch.tensor(ranks, dtype=torch.float, device=device)
    mrr = (1.0 / ranks).mean().item()
    hits = {(f"Hits@{k}"): (ranks <= k).float().mean().item() for k in k_values}
    return mrr, hits

# %%
# Load triples
train_triples = load_triples("../graph_data/train.tsv")
dev_triples =  load_triples("../graph_data/dev.tsv")
test_triples =  load_triples("../graph_data/test.tsv")

# Build vocab
entities = set()
relations = set()
for h, r, t in train_triples + dev_triples:
    entities.update([h, t]); relations.add(r)
ent2id = {e: i for i, e in enumerate(sorted(entities))}
rel2id = {r: i for i, r in enumerate(sorted(relations))}

# %%
# Encode triples
def encode(triples):
    return torch.tensor([[ent2id[h], rel2id[r], ent2id[t]] for h, r, t in triples], dtype=torch.long)

train_data = encode(train_triples)

dev_data = encode(dev_triples)

test_data = encode(test_triples)

# %%
embedding_dim = 100 
batch_size = 512
lr = 5e-4 
weight_decay = 1e-4 
epochs = 500
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data loaders
train_loader = DataLoader(TensorDataset(train_data), batch_size=512, shuffle=True)
dev_loader = DataLoader(TensorDataset(dev_data), batch_size=512)

# Model & optimizer
num_entities = len(ent2id)
num_relations = len(rel2id)
model = DistMultModel(num_entities, num_relations,  embedding_dim).to( device)
optimizer = AdamW(model.parameters(), lr= lr, weight_decay= weight_decay)

# %%
# Training loop
best_dev_loss = float('inf')
for epoch in range(1,  epochs + 1):
    train_loss = train_epoch(model, optimizer, train_loader, num_entities, device)
    dev_loss = evaluate_loss(model, dev_loader, device)
    print(f"Epoch {epoch:03d} | Train Loss: {train_loss:.4f} | Dev Loss: {dev_loss:.4f}")

    # Early stopping on dev loss
    if dev_loss < best_dev_loss:
        best_dev_loss = dev_loss
        torch.save(model.state_dict(), 'best_distmult.pt')
# Out:
# Epoch 001 | Train Loss: 1.3863 | Dev Loss: 0.6932
# Epoch 002 | Train Loss: 1.3861 | Dev Loss: 0.6932
# Epoch 003 | Train Loss: 1.3859 | Dev Loss: 0.6932
# Epoch 004 | Train Loss: 1.3857 | Dev Loss: 0.6932
# Epoch 005 | Train Loss: 1.3855 | Dev Loss: 0.6932
# Epoch 006 | Train Loss: 1.3853 | Dev Loss: 0.6932
# Epoch 007 | Train Loss: 1.3850 | Dev Loss: 0.6931
# Epoch 008 | Train Loss: 1.3847 | Dev Loss: 0.6931
# Epoch 009 | Train Loss: 1.3843 | Dev Loss: 0.6931
# Epoch 010 | Train Loss: 1.3839 | Dev Loss: 0.6931
# Epoch 011 | Train Loss: 1.3835 | Dev Loss: 0.6930
# Epoch 012 | Train Loss: 1.3829 | Dev Loss: 0.6930
# Epoch 013 | Train Loss: 1.3823 | Dev Loss: 0.6929
# Epoch 014 | Train Loss: 1.3815 | Dev Loss: 0.6929
# Epoch 015 | Train Loss: 1.3807 | Dev Loss: 0.6928
# Epoch 016 | Train Loss: 1.3797 | Dev Loss: 0.6927
# Epoch 017 | Train Loss: 1.3786 | Dev Loss: 0.6925
# Epoch 018 | Train Loss: 1.3774 | Dev Loss: 0.6924
# Epoch 019 | Train Loss: 1.3759 | Dev Loss: 0.6922
# Epoch 020 | Train Loss: 1.3743 | Dev Loss: 0.6919
# Epoch 021 | Train Loss: 1.3725 | Dev Loss: 0.6917
# Epoch 022 | Train Loss: 1.3705 | Dev Loss: 0.6913
# Epoch 023 | Train Loss: 1.3682 | Dev Loss: 0.6910
# Epoch 024 | Train Loss: 1.3657 | Dev Loss: 0.6905
# Epoch 025 | Train Loss: 1.3629 | Dev Loss: 0.6901
# Epoch 026 | Train Loss: 1.3599 | Dev Loss: 0.6895
# Epoch 027 | Train Loss: 1.3565 | Dev Loss: 0.6889
# Epoch 028 | Train Loss: 1.3528 | Dev Loss: 0.6882
# Epoch 029 | Train Loss: 1.3489 | Dev Loss: 0.6875
# Epoch 030 | Train Loss: 1.3445 | Dev Loss: 0.6867
# Epoch 031 | Train Loss: 1.3397 | Dev Loss: 0.6858
# Epoch 032 | Train Loss: 1.3348 | Dev Loss: 0.6849
# Epoch 033 | Train Loss: 1.3295 | Dev Loss: 0.6838
# Epoch 034 | Train Loss: 1.3236 | Dev Loss: 0.6827
# Epoch 035 | Train Loss: 1.3177 | Dev Loss: 0.6815
# Epoch 036 | Train Loss: 1.3110 | Dev Loss: 0.6801
# Epoch 037 | Train Loss: 1.3042 | Dev Loss: 0.6786
# Epoch 038 | Train Loss: 1.2972 | Dev Loss: 0.6771
# Epoch 039 | Train Loss: 1.2899 | Dev Loss: 0.6754
# Epoch 040 | Train Loss: 1.2818 | Dev Loss: 0.6737
# Epoch 041 | Train Loss: 1.2737 | Dev Loss: 0.6718
# Epoch 042 | Train Loss: 1.2655 | Dev Loss: 0.6700
# Epoch 043 | Train Loss: 1.2563 | Dev Loss: 0.6680
# Epoch 044 | Train Loss: 1.2479 | Dev Loss: 0.6662
# Epoch 045 | Train Loss: 1.2378 | Dev Loss: 0.6640
# Epoch 046 | Train Loss: 1.2286 | Dev Loss: 0.6618
# Epoch 047 | Train Loss: 1.2192 | Dev Loss: 0.6595
# Epoch 048 | Train Loss: 1.2092 | Dev Loss: 0.6572
# Epoch 049 | Train Loss: 1.1991 | Dev Loss: 0.6549
# Epoch 050 | Train Loss: 1.1886 | Dev Loss: 0.6525
# Epoch 051 | Train Loss: 1.1786 | Dev Loss: 0.6502
# Epoch 052 | Train Loss: 1.1682 | Dev Loss: 0.6477
# Epoch 053 | Train Loss: 1.1572 | Dev Loss: 0.6452
# Epoch 054 | Train Loss: 1.1470 | Dev Loss: 0.6428
# Epoch 055 | Train Loss: 1.1371 | Dev Loss: 0.6404
# Epoch 056 | Train Loss: 1.1251 | Dev Loss: 0.6378
# Epoch 057 | Train Loss: 1.1154 | Dev Loss: 0.6351
# Epoch 058 | Train Loss: 1.1057 | Dev Loss: 0.6327
# Epoch 059 | Train Loss: 1.0947 | Dev Loss: 0.6302
# Epoch 060 | Train Loss: 1.0855 | Dev Loss: 0.6277
# Epoch 061 | Train Loss: 1.0757 | Dev Loss: 0.6250
# Epoch 062 | Train Loss: 1.0654 | Dev Loss: 0.6225
# Epoch 063 | Train Loss: 1.0551 | Dev Loss: 0.6201
# Epoch 064 | Train Loss: 1.0453 | Dev Loss: 0.6179
# Epoch 065 | Train Loss: 1.0372 | Dev Loss: 0.6157
# Epoch 066 | Train Loss: 1.0266 | Dev Loss: 0.6138
# Epoch 067 | Train Loss: 1.0191 | Dev Loss: 0.6118
# Epoch 068 | Train Loss: 1.0088 | Dev Loss: 0.6098
# Epoch 069 | Train Loss: 1.0004 | Dev Loss: 0.6077
# Epoch 070 | Train Loss: 0.9942 | Dev Loss: 0.6058
# Epoch 071 | Train Loss: 0.9853 | Dev Loss: 0.6039
# Epoch 072 | Train Loss: 0.9775 | Dev Loss: 0.6019
# Epoch 073 | Train Loss: 0.9675 | Dev Loss: 0.6002
# Epoch 074 | Train Loss: 0.9606 | Dev Loss: 0.5984
# Epoch 075 | Train Loss: 0.9554 | Dev Loss: 0.5967
# Epoch 076 | Train Loss: 0.9486 | Dev Loss: 0.5950
# Epoch 077 | Train Loss: 0.9387 | Dev Loss: 0.5935
# Epoch 078 | Train Loss: 0.9339 | Dev Loss: 0.5919
# Epoch 079 | Train Loss: 0.9289 | Dev Loss: 0.5902
# Epoch 080 | Train Loss: 0.9222 | Dev Loss: 0.5886
# Epoch 081 | Train Loss: 0.9159 | Dev Loss: 0.5871
# Epoch 082 | Train Loss: 0.9101 | Dev Loss: 0.5859
# Epoch 083 | Train Loss: 0.9028 | Dev Loss: 0.5845
# Epoch 084 | Train Loss: 0.8999 | Dev Loss: 0.5832
# Epoch 085 | Train Loss: 0.8935 | Dev Loss: 0.5819
# Epoch 086 | Train Loss: 0.8898 | Dev Loss: 0.5807
# Epoch 087 | Train Loss: 0.8850 | Dev Loss: 0.5797
# Epoch 088 | Train Loss: 0.8796 | Dev Loss: 0.5785
# Epoch 089 | Train Loss: 0.8758 | Dev Loss: 0.5777
# Epoch 090 | Train Loss: 0.8724 | Dev Loss: 0.5773
# Epoch 091 | Train Loss: 0.8664 | Dev Loss: 0.5767
# Epoch 092 | Train Loss: 0.8621 | Dev Loss: 0.5759
# Epoch 093 | Train Loss: 0.8575 | Dev Loss: 0.5749
# Epoch 094 | Train Loss: 0.8536 | Dev Loss: 0.5739
# Epoch 095 | Train Loss: 0.8535 | Dev Loss: 0.5728
# Epoch 096 | Train Loss: 0.8488 | Dev Loss: 0.5721
# Epoch 097 | Train Loss: 0.8441 | Dev Loss: 0.5715
# Epoch 098 | Train Loss: 0.8422 | Dev Loss: 0.5709
# Epoch 099 | Train Loss: 0.8361 | Dev Loss: 0.5701
# Epoch 100 | Train Loss: 0.8376 | Dev Loss: 0.5691
# Epoch 101 | Train Loss: 0.8333 | Dev Loss: 0.5684
# Epoch 102 | Train Loss: 0.8285 | Dev Loss: 0.5675
# Epoch 103 | Train Loss: 0.8273 | Dev Loss: 0.5667
# Epoch 104 | Train Loss: 0.8246 | Dev Loss: 0.5659
# Epoch 105 | Train Loss: 0.8187 | Dev Loss: 0.5652
# Epoch 106 | Train Loss: 0.8200 | Dev Loss: 0.5648
# Epoch 107 | Train Loss: 0.8186 | Dev Loss: 0.5644
# Epoch 108 | Train Loss: 0.8117 | Dev Loss: 0.5638
# Epoch 109 | Train Loss: 0.8093 | Dev Loss: 0.5632
# Epoch 110 | Train Loss: 0.8096 | Dev Loss: 0.5629
# Epoch 111 | Train Loss: 0.8098 | Dev Loss: 0.5627
# Epoch 112 | Train Loss: 0.8083 | Dev Loss: 0.5623
# Epoch 113 | Train Loss: 0.8080 | Dev Loss: 0.5619
# Epoch 114 | Train Loss: 0.8010 | Dev Loss: 0.5616
# Epoch 115 | Train Loss: 0.8022 | Dev Loss: 0.5612
# Epoch 116 | Train Loss: 0.8016 | Dev Loss: 0.5614
# Epoch 117 | Train Loss: 0.7973 | Dev Loss: 0.5615
# Epoch 118 | Train Loss: 0.7951 | Dev Loss: 0.5619
# Epoch 119 | Train Loss: 0.7934 | Dev Loss: 0.5618
# Epoch 120 | Train Loss: 0.7943 | Dev Loss: 0.5614
# Epoch 121 | Train Loss: 0.7996 | Dev Loss: 0.5610
# Epoch 122 | Train Loss: 0.7927 | Dev Loss: 0.5608
# Epoch 123 | Train Loss: 0.7871 | Dev Loss: 0.5608
# Epoch 124 | Train Loss: 0.7874 | Dev Loss: 0.5610
# Epoch 125 | Train Loss: 0.7826 | Dev Loss: 0.5610
# Epoch 126 | Train Loss: 0.7857 | Dev Loss: 0.5607
# Epoch 127 | Train Loss: 0.7833 | Dev Loss: 0.5607
# Epoch 128 | Train Loss: 0.7800 | Dev Loss: 0.5606
# Epoch 129 | Train Loss: 0.7782 | Dev Loss: 0.5605
# Epoch 130 | Train Loss: 0.7766 | Dev Loss: 0.5603
# Epoch 131 | Train Loss: 0.7749 | Dev Loss: 0.5600
# Epoch 132 | Train Loss: 0.7732 | Dev Loss: 0.5601
# Epoch 133 | Train Loss: 0.7724 | Dev Loss: 0.5599
# Epoch 134 | Train Loss: 0.7782 | Dev Loss: 0.5596
# Epoch 135 | Train Loss: 0.7758 | Dev Loss: 0.5594
# Epoch 136 | Train Loss: 0.7699 | Dev Loss: 0.5593
# Epoch 137 | Train Loss: 0.7702 | Dev Loss: 0.5592
# Epoch 138 | Train Loss: 0.7691 | Dev Loss: 0.5591
# Epoch 139 | Train Loss: 0.7687 | Dev Loss: 0.5589
# Epoch 140 | Train Loss: 0.7723 | Dev Loss: 0.5586
# Epoch 141 | Train Loss: 0.7693 | Dev Loss: 0.5584
# Epoch 142 | Train Loss: 0.7711 | Dev Loss: 0.5583
# Epoch 143 | Train Loss: 0.7722 | Dev Loss: 0.5582
# Epoch 144 | Train Loss: 0.7669 | Dev Loss: 0.5580
# Epoch 145 | Train Loss: 0.7703 | Dev Loss: 0.5576
# Epoch 146 | Train Loss: 0.7630 | Dev Loss: 0.5570
# Epoch 147 | Train Loss: 0.7696 | Dev Loss: 0.5566
# Epoch 148 | Train Loss: 0.7652 | Dev Loss: 0.5566
# Epoch 149 | Train Loss: 0.7635 | Dev Loss: 0.5566
# Epoch 150 | Train Loss: 0.7622 | Dev Loss: 0.5563
# Epoch 151 | Train Loss: 0.7606 | Dev Loss: 0.5561
# Epoch 152 | Train Loss: 0.7607 | Dev Loss: 0.5560
# Epoch 153 | Train Loss: 0.7616 | Dev Loss: 0.5561
# Epoch 154 | Train Loss: 0.7605 | Dev Loss: 0.5559
# Epoch 155 | Train Loss: 0.7618 | Dev Loss: 0.5558
# Epoch 156 | Train Loss: 0.7566 | Dev Loss: 0.5557
# Epoch 157 | Train Loss: 0.7612 | Dev Loss: 0.5553
# Epoch 158 | Train Loss: 0.7558 | Dev Loss: 0.5552
# Epoch 159 | Train Loss: 0.7554 | Dev Loss: 0.5553
# Epoch 160 | Train Loss: 0.7569 | Dev Loss: 0.5552
# Epoch 161 | Train Loss: 0.7533 | Dev Loss: 0.5554
# Epoch 162 | Train Loss: 0.7548 | Dev Loss: 0.5555
# Epoch 163 | Train Loss: 0.7590 | Dev Loss: 0.5556
# Epoch 164 | Train Loss: 0.7540 | Dev Loss: 0.5553
# Epoch 165 | Train Loss: 0.7539 | Dev Loss: 0.5550
# Epoch 166 | Train Loss: 0.7565 | Dev Loss: 0.5549
# Epoch 167 | Train Loss: 0.7543 | Dev Loss: 0.5544
# Epoch 168 | Train Loss: 0.7545 | Dev Loss: 0.5538
# Epoch 169 | Train Loss: 0.7548 | Dev Loss: 0.5536
# Epoch 170 | Train Loss: 0.7564 | Dev Loss: 0.5537
# Epoch 171 | Train Loss: 0.7524 | Dev Loss: 0.5536
# Epoch 172 | Train Loss: 0.7516 | Dev Loss: 0.5536
# Epoch 173 | Train Loss: 0.7528 | Dev Loss: 0.5534
# Epoch 174 | Train Loss: 0.7477 | Dev Loss: 0.5534
# Epoch 175 | Train Loss: 0.7586 | Dev Loss: 0.5534
# Epoch 176 | Train Loss: 0.7497 | Dev Loss: 0.5535
# Epoch 177 | Train Loss: 0.7509 | Dev Loss: 0.5540
# Epoch 178 | Train Loss: 0.7483 | Dev Loss: 0.5542
# Epoch 179 | Train Loss: 0.7493 | Dev Loss: 0.5543
# Epoch 180 | Train Loss: 0.7457 | Dev Loss: 0.5545
# Epoch 181 | Train Loss: 0.7506 | Dev Loss: 0.5545
# Epoch 182 | Train Loss: 0.7503 | Dev Loss: 0.5546
# Epoch 183 | Train Loss: 0.7450 | Dev Loss: 0.5543
# Epoch 184 | Train Loss: 0.7465 | Dev Loss: 0.5538
# Epoch 185 | Train Loss: 0.7516 | Dev Loss: 0.5534
# Epoch 186 | Train Loss: 0.7475 | Dev Loss: 0.5534
# Epoch 187 | Train Loss: 0.7453 | Dev Loss: 0.5537
# Epoch 188 | Train Loss: 0.7463 | Dev Loss: 0.5539
# Epoch 189 | Train Loss: 0.7470 | Dev Loss: 0.5538
# Epoch 190 | Train Loss: 0.7521 | Dev Loss: 0.5537
# Epoch 191 | Train Loss: 0.7483 | Dev Loss: 0.5535
# Epoch 192 | Train Loss: 0.7411 | Dev Loss: 0.5534
# Epoch 193 | Train Loss: 0.7490 | Dev Loss: 0.5535
# Epoch 194 | Train Loss: 0.7462 | Dev Loss: 0.5536
# Epoch 195 | Train Loss: 0.7424 | Dev Loss: 0.5535
# Epoch 196 | Train Loss: 0.7446 | Dev Loss: 0.5536
# Epoch 197 | Train Loss: 0.7495 | Dev Loss: 0.5537
# Epoch 198 | Train Loss: 0.7405 | Dev Loss: 0.5538
# Epoch 199 | Train Loss: 0.7437 | Dev Loss: 0.5539
# Epoch 200 | Train Loss: 0.7431 | Dev Loss: 0.5542
# Epoch 201 | Train Loss: 0.7436 | Dev Loss: 0.5543
# Epoch 202 | Train Loss: 0.7417 | Dev Loss: 0.5545
# Epoch 203 | Train Loss: 0.7412 | Dev Loss: 0.5544
# Epoch 204 | Train Loss: 0.7461 | Dev Loss: 0.5544
# Epoch 205 | Train Loss: 0.7390 | Dev Loss: 0.5543
# Epoch 206 | Train Loss: 0.7390 | Dev Loss: 0.5543
# Epoch 207 | Train Loss: 0.7431 | Dev Loss: 0.5541
# Epoch 208 | Train Loss: 0.7485 | Dev Loss: 0.5540
# Epoch 209 | Train Loss: 0.7517 | Dev Loss: 0.5540
# Epoch 210 | Train Loss: 0.7399 | Dev Loss: 0.5539
# Epoch 211 | Train Loss: 0.7473 | Dev Loss: 0.5539
# Epoch 212 | Train Loss: 0.7450 | Dev Loss: 0.5541
# Epoch 213 | Train Loss: 0.7385 | Dev Loss: 0.5540
# Epoch 214 | Train Loss: 0.7401 | Dev Loss: 0.5540
# Epoch 215 | Train Loss: 0.7415 | Dev Loss: 0.5540
# Epoch 216 | Train Loss: 0.7401 | Dev Loss: 0.5543
# Epoch 217 | Train Loss: 0.7444 | Dev Loss: 0.5545
# Epoch 218 | Train Loss: 0.7478 | Dev Loss: 0.5548
# Epoch 219 | Train Loss: 0.7392 | Dev Loss: 0.5549
# Epoch 220 | Train Loss: 0.7395 | Dev Loss: 0.5550
# Epoch 221 | Train Loss: 0.7419 | Dev Loss: 0.5553
# Epoch 222 | Train Loss: 0.7407 | Dev Loss: 0.5556
# Epoch 223 | Train Loss: 0.7442 | Dev Loss: 0.5555
# Epoch 224 | Train Loss: 0.7432 | Dev Loss: 0.5553
# Epoch 225 | Train Loss: 0.7357 | Dev Loss: 0.5552
# Epoch 226 | Train Loss: 0.7381 | Dev Loss: 0.5549
# Epoch 227 | Train Loss: 0.7399 | Dev Loss: 0.5546
# Epoch 228 | Train Loss: 0.7449 | Dev Loss: 0.5546
# Epoch 229 | Train Loss: 0.7414 | Dev Loss: 0.5546
# Epoch 230 | Train Loss: 0.7374 | Dev Loss: 0.5542
# Epoch 231 | Train Loss: 0.7428 | Dev Loss: 0.5540
# Epoch 232 | Train Loss: 0.7417 | Dev Loss: 0.5536
# Epoch 233 | Train Loss: 0.7409 | Dev Loss: 0.5535
# Epoch 234 | Train Loss: 0.7306 | Dev Loss: 0.5538
# Epoch 235 | Train Loss: 0.7437 | Dev Loss: 0.5542
# Epoch 236 | Train Loss: 0.7357 | Dev Loss: 0.5541
# Epoch 237 | Train Loss: 0.7399 | Dev Loss: 0.5540
# Epoch 238 | Train Loss: 0.7365 | Dev Loss: 0.5542
# Epoch 239 | Train Loss: 0.7366 | Dev Loss: 0.5547
# Epoch 240 | Train Loss: 0.7417 | Dev Loss: 0.5548
# Epoch 241 | Train Loss: 0.7385 | Dev Loss: 0.5550
# Epoch 242 | Train Loss: 0.7414 | Dev Loss: 0.5552
# Epoch 243 | Train Loss: 0.7394 | Dev Loss: 0.5555
# Epoch 244 | Train Loss: 0.7382 | Dev Loss: 0.5554
# Epoch 245 | Train Loss: 0.7374 | Dev Loss: 0.5554
# Epoch 246 | Train Loss: 0.7351 | Dev Loss: 0.5554
# Epoch 247 | Train Loss: 0.7392 | Dev Loss: 0.5552
# Epoch 248 | Train Loss: 0.7350 | Dev Loss: 0.5552
# Epoch 249 | Train Loss: 0.7369 | Dev Loss: 0.5553
# Epoch 250 | Train Loss: 0.7370 | Dev Loss: 0.5553
# Epoch 251 | Train Loss: 0.7335 | Dev Loss: 0.5550
# Epoch 252 | Train Loss: 0.7434 | Dev Loss: 0.5548
# Epoch 253 | Train Loss: 0.7443 | Dev Loss: 0.5546
# Epoch 254 | Train Loss: 0.7388 | Dev Loss: 0.5545
# Epoch 255 | Train Loss: 0.7323 | Dev Loss: 0.5543
# Epoch 256 | Train Loss: 0.7392 | Dev Loss: 0.5538
# Epoch 257 | Train Loss: 0.7369 | Dev Loss: 0.5535
# Epoch 258 | Train Loss: 0.7317 | Dev Loss: 0.5534
# Epoch 259 | Train Loss: 0.7352 | Dev Loss: 0.5535
# Epoch 260 | Train Loss: 0.7386 | Dev Loss: 0.5536
# Epoch 261 | Train Loss: 0.7397 | Dev Loss: 0.5541
# Epoch 262 | Train Loss: 0.7331 | Dev Loss: 0.5545
# Epoch 263 | Train Loss: 0.7352 | Dev Loss: 0.5545
# Epoch 264 | Train Loss: 0.7336 | Dev Loss: 0.5544
# Epoch 265 | Train Loss: 0.7338 | Dev Loss: 0.5546
# Epoch 266 | Train Loss: 0.7408 | Dev Loss: 0.5543
# Epoch 267 | Train Loss: 0.7380 | Dev Loss: 0.5543
# Epoch 268 | Train Loss: 0.7358 | Dev Loss: 0.5547
# Epoch 269 | Train Loss: 0.7376 | Dev Loss: 0.5551
# Epoch 270 | Train Loss: 0.7367 | Dev Loss: 0.5554
# Epoch 271 | Train Loss: 0.7344 | Dev Loss: 0.5555
# Epoch 272 | Train Loss: 0.7347 | Dev Loss: 0.5553
# Epoch 273 | Train Loss: 0.7304 | Dev Loss: 0.5552
# Epoch 274 | Train Loss: 0.7393 | Dev Loss: 0.5553
# Epoch 275 | Train Loss: 0.7329 | Dev Loss: 0.5553
# Epoch 276 | Train Loss: 0.7365 | Dev Loss: 0.5552
# Epoch 277 | Train Loss: 0.7324 | Dev Loss: 0.5554
# Epoch 278 | Train Loss: 0.7442 | Dev Loss: 0.5559
# Epoch 279 | Train Loss: 0.7367 | Dev Loss: 0.5560
# Epoch 280 | Train Loss: 0.7394 | Dev Loss: 0.5557
# Epoch 281 | Train Loss: 0.7329 | Dev Loss: 0.5554
# Epoch 282 | Train Loss: 0.7356 | Dev Loss: 0.5552
# Epoch 283 | Train Loss: 0.7365 | Dev Loss: 0.5551
# Epoch 284 | Train Loss: 0.7407 | Dev Loss: 0.5552
# Epoch 285 | Train Loss: 0.7313 | Dev Loss: 0.5551
# Epoch 286 | Train Loss: 0.7329 | Dev Loss: 0.5548
# Epoch 287 | Train Loss: 0.7353 | Dev Loss: 0.5546
# Epoch 288 | Train Loss: 0.7328 | Dev Loss: 0.5547
# Epoch 289 | Train Loss: 0.7360 | Dev Loss: 0.5546
# Epoch 290 | Train Loss: 0.7383 | Dev Loss: 0.5544
# Epoch 291 | Train Loss: 0.7332 | Dev Loss: 0.5542
# Epoch 292 | Train Loss: 0.7353 | Dev Loss: 0.5539
# Epoch 293 | Train Loss: 0.7367 | Dev Loss: 0.5538
# Epoch 294 | Train Loss: 0.7335 | Dev Loss: 0.5536
# Epoch 295 | Train Loss: 0.7365 | Dev Loss: 0.5534
# Epoch 296 | Train Loss: 0.7336 | Dev Loss: 0.5531
# Epoch 297 | Train Loss: 0.7322 | Dev Loss: 0.5529
# Epoch 298 | Train Loss: 0.7314 | Dev Loss: 0.5530
# Epoch 299 | Train Loss: 0.7363 | Dev Loss: 0.5532
# Epoch 300 | Train Loss: 0.7305 | Dev Loss: 0.5532
# Epoch 301 | Train Loss: 0.7346 | Dev Loss: 0.5534
# Epoch 302 | Train Loss: 0.7288 | Dev Loss: 0.5530
# Epoch 303 | Train Loss: 0.7340 | Dev Loss: 0.5529
# Epoch 304 | Train Loss: 0.7307 | Dev Loss: 0.5529
# Epoch 305 | Train Loss: 0.7370 | Dev Loss: 0.5527
# Epoch 306 | Train Loss: 0.7360 | Dev Loss: 0.5528
# Epoch 307 | Train Loss: 0.7363 | Dev Loss: 0.5529
# Epoch 308 | Train Loss: 0.7354 | Dev Loss: 0.5533
# Epoch 309 | Train Loss: 0.7298 | Dev Loss: 0.5536
# Epoch 310 | Train Loss: 0.7301 | Dev Loss: 0.5541
# Epoch 311 | Train Loss: 0.7360 | Dev Loss: 0.5547
# Epoch 312 | Train Loss: 0.7278 | Dev Loss: 0.5552
# Epoch 313 | Train Loss: 0.7343 | Dev Loss: 0.5556
# Epoch 314 | Train Loss: 0.7354 | Dev Loss: 0.5560
# Epoch 315 | Train Loss: 0.7340 | Dev Loss: 0.5564
# Epoch 316 | Train Loss: 0.7282 | Dev Loss: 0.5567
# Epoch 317 | Train Loss: 0.7362 | Dev Loss: 0.5570
# Epoch 318 | Train Loss: 0.7324 | Dev Loss: 0.5573
# Epoch 319 | Train Loss: 0.7357 | Dev Loss: 0.5571
# Epoch 320 | Train Loss: 0.7329 | Dev Loss: 0.5569
# Epoch 321 | Train Loss: 0.7312 | Dev Loss: 0.5568
# Epoch 322 | Train Loss: 0.7318 | Dev Loss: 0.5569
# Epoch 323 | Train Loss: 0.7291 | Dev Loss: 0.5569
# Epoch 324 | Train Loss: 0.7369 | Dev Loss: 0.5569
# Epoch 325 | Train Loss: 0.7285 | Dev Loss: 0.5570
# Epoch 326 | Train Loss: 0.7368 | Dev Loss: 0.5570
# Epoch 327 | Train Loss: 0.7330 | Dev Loss: 0.5571
# Epoch 328 | Train Loss: 0.7348 | Dev Loss: 0.5575
# Epoch 329 | Train Loss: 0.7320 | Dev Loss: 0.5579
# Epoch 330 | Train Loss: 0.7322 | Dev Loss: 0.5584
# Epoch 331 | Train Loss: 0.7336 | Dev Loss: 0.5588
# Epoch 332 | Train Loss: 0.7319 | Dev Loss: 0.5590
# Epoch 333 | Train Loss: 0.7342 | Dev Loss: 0.5592
# Epoch 334 | Train Loss: 0.7318 | Dev Loss: 0.5589
# Epoch 335 | Train Loss: 0.7286 | Dev Loss: 0.5584
# Epoch 336 | Train Loss: 0.7326 | Dev Loss: 0.5581
# Epoch 337 | Train Loss: 0.7282 | Dev Loss: 0.5582
# Epoch 338 | Train Loss: 0.7295 | Dev Loss: 0.5583
# Epoch 339 | Train Loss: 0.7319 | Dev Loss: 0.5587
# Epoch 340 | Train Loss: 0.7307 | Dev Loss: 0.5589
# Epoch 341 | Train Loss: 0.7302 | Dev Loss: 0.5591
# Epoch 342 | Train Loss: 0.7333 | Dev Loss: 0.5591
# Epoch 343 | Train Loss: 0.7339 | Dev Loss: 0.5589
# Epoch 344 | Train Loss: 0.7355 | Dev Loss: 0.5586
# Epoch 345 | Train Loss: 0.7302 | Dev Loss: 0.5583
# Epoch 346 | Train Loss: 0.7385 | Dev Loss: 0.5583
# Epoch 347 | Train Loss: 0.7345 | Dev Loss: 0.5582
# Epoch 348 | Train Loss: 0.7279 | Dev Loss: 0.5585
# Epoch 349 | Train Loss: 0.7292 | Dev Loss: 0.5588
# Epoch 350 | Train Loss: 0.7366 | Dev Loss: 0.5589
# Epoch 351 | Train Loss: 0.7343 | Dev Loss: 0.5587
# Epoch 352 | Train Loss: 0.7323 | Dev Loss: 0.5585
# Epoch 353 | Train Loss: 0.7370 | Dev Loss: 0.5584
# Epoch 354 | Train Loss: 0.7333 | Dev Loss: 0.5585
# Epoch 355 | Train Loss: 0.7243 | Dev Loss: 0.5590
# Epoch 356 | Train Loss: 0.7286 | Dev Loss: 0.5591
# Epoch 357 | Train Loss: 0.7331 | Dev Loss: 0.5592
# Epoch 358 | Train Loss: 0.7313 | Dev Loss: 0.5590
# Epoch 359 | Train Loss: 0.7308 | Dev Loss: 0.5589
# Epoch 360 | Train Loss: 0.7360 | Dev Loss: 0.5587
# Epoch 361 | Train Loss: 0.7293 | Dev Loss: 0.5584
# Epoch 362 | Train Loss: 0.7299 | Dev Loss: 0.5586
# Epoch 363 | Train Loss: 0.7245 | Dev Loss: 0.5587
# Epoch 364 | Train Loss: 0.7305 | Dev Loss: 0.5590
# Epoch 365 | Train Loss: 0.7313 | Dev Loss: 0.5590
# Epoch 366 | Train Loss: 0.7312 | Dev Loss: 0.5591
# Epoch 367 | Train Loss: 0.7370 | Dev Loss: 0.5595
# Epoch 368 | Train Loss: 0.7341 | Dev Loss: 0.5595
# Epoch 369 | Train Loss: 0.7335 | Dev Loss: 0.5595
# Epoch 370 | Train Loss: 0.7302 | Dev Loss: 0.5594
# Epoch 371 | Train Loss: 0.7333 | Dev Loss: 0.5596
# Epoch 372 | Train Loss: 0.7221 | Dev Loss: 0.5598
# Epoch 373 | Train Loss: 0.7300 | Dev Loss: 0.5602
# Epoch 374 | Train Loss: 0.7304 | Dev Loss: 0.5606
# Epoch 375 | Train Loss: 0.7311 | Dev Loss: 0.5611
# Epoch 376 | Train Loss: 0.7339 | Dev Loss: 0.5614
# Epoch 377 | Train Loss: 0.7337 | Dev Loss: 0.5614
# Epoch 378 | Train Loss: 0.7288 | Dev Loss: 0.5615
# Epoch 379 | Train Loss: 0.7266 | Dev Loss: 0.5613
# Epoch 380 | Train Loss: 0.7300 | Dev Loss: 0.5611
# Epoch 381 | Train Loss: 0.7346 | Dev Loss: 0.5610
# Epoch 382 | Train Loss: 0.7317 | Dev Loss: 0.5609
# Epoch 383 | Train Loss: 0.7224 | Dev Loss: 0.5610
# Epoch 384 | Train Loss: 0.7344 | Dev Loss: 0.5612
# Epoch 385 | Train Loss: 0.7258 | Dev Loss: 0.5615
# Epoch 386 | Train Loss: 0.7342 | Dev Loss: 0.5618
# Epoch 387 | Train Loss: 0.7294 | Dev Loss: 0.5617
# Epoch 388 | Train Loss: 0.7306 | Dev Loss: 0.5617
# Epoch 389 | Train Loss: 0.7320 | Dev Loss: 0.5618
# Epoch 390 | Train Loss: 0.7335 | Dev Loss: 0.5619
# Epoch 391 | Train Loss: 0.7298 | Dev Loss: 0.5622
# Epoch 392 | Train Loss: 0.7279 | Dev Loss: 0.5626
# Epoch 393 | Train Loss: 0.7305 | Dev Loss: 0.5628
# Epoch 394 | Train Loss: 0.7278 | Dev Loss: 0.5631
# Epoch 395 | Train Loss: 0.7309 | Dev Loss: 0.5632
# Epoch 396 | Train Loss: 0.7298 | Dev Loss: 0.5634
# Epoch 397 | Train Loss: 0.7320 | Dev Loss: 0.5636
# Epoch 398 | Train Loss: 0.7354 | Dev Loss: 0.5638
# Epoch 399 | Train Loss: 0.7310 | Dev Loss: 0.5641
# Epoch 400 | Train Loss: 0.7256 | Dev Loss: 0.5638
# Epoch 401 | Train Loss: 0.7334 | Dev Loss: 0.5639
# Epoch 402 | Train Loss: 0.7251 | Dev Loss: 0.5641
# Epoch 403 | Train Loss: 0.7315 | Dev Loss: 0.5644
# Epoch 404 | Train Loss: 0.7293 | Dev Loss: 0.5647
# Epoch 405 | Train Loss: 0.7372 | Dev Loss: 0.5650
# Epoch 406 | Train Loss: 0.7294 | Dev Loss: 0.5652
# Epoch 407 | Train Loss: 0.7332 | Dev Loss: 0.5657
# Epoch 408 | Train Loss: 0.7291 | Dev Loss: 0.5660
# Epoch 409 | Train Loss: 0.7304 | Dev Loss: 0.5658
# Epoch 410 | Train Loss: 0.7254 | Dev Loss: 0.5659
# Epoch 411 | Train Loss: 0.7270 | Dev Loss: 0.5665
# Epoch 412 | Train Loss: 0.7315 | Dev Loss: 0.5668
# Epoch 413 | Train Loss: 0.7269 | Dev Loss: 0.5669
# Epoch 414 | Train Loss: 0.7310 | Dev Loss: 0.5670
# Epoch 415 | Train Loss: 0.7238 | Dev Loss: 0.5671
# Epoch 416 | Train Loss: 0.7342 | Dev Loss: 0.5672
# Epoch 417 | Train Loss: 0.7247 | Dev Loss: 0.5673
# Epoch 418 | Train Loss: 0.7289 | Dev Loss: 0.5673
# Epoch 419 | Train Loss: 0.7284 | Dev Loss: 0.5672
# Epoch 420 | Train Loss: 0.7270 | Dev Loss: 0.5670
# Epoch 421 | Train Loss: 0.7293 | Dev Loss: 0.5667
# Epoch 422 | Train Loss: 0.7290 | Dev Loss: 0.5667
# Epoch 423 | Train Loss: 0.7261 | Dev Loss: 0.5669
# Epoch 424 | Train Loss: 0.7262 | Dev Loss: 0.5669
# Epoch 425 | Train Loss: 0.7289 | Dev Loss: 0.5671
# Epoch 426 | Train Loss: 0.7253 | Dev Loss: 0.5671
# Epoch 427 | Train Loss: 0.7224 | Dev Loss: 0.5669
# Epoch 428 | Train Loss: 0.7212 | Dev Loss: 0.5668
# Epoch 429 | Train Loss: 0.7299 | Dev Loss: 0.5668
# Epoch 430 | Train Loss: 0.7303 | Dev Loss: 0.5663
# Epoch 431 | Train Loss: 0.7260 | Dev Loss: 0.5662
# Epoch 432 | Train Loss: 0.7235 | Dev Loss: 0.5660
# Epoch 433 | Train Loss: 0.7258 | Dev Loss: 0.5659
# Epoch 434 | Train Loss: 0.7203 | Dev Loss: 0.5659
# Epoch 435 | Train Loss: 0.7234 | Dev Loss: 0.5659
# Epoch 436 | Train Loss: 0.7289 | Dev Loss: 0.5662
# Epoch 437 | Train Loss: 0.7262 | Dev Loss: 0.5665
# Epoch 438 | Train Loss: 0.7325 | Dev Loss: 0.5665
# Epoch 439 | Train Loss: 0.7211 | Dev Loss: 0.5667
# Epoch 440 | Train Loss: 0.7263 | Dev Loss: 0.5663
# Epoch 441 | Train Loss: 0.7238 | Dev Loss: 0.5661
# Epoch 442 | Train Loss: 0.7249 | Dev Loss: 0.5661
# Epoch 443 | Train Loss: 0.7234 | Dev Loss: 0.5665
# Epoch 444 | Train Loss: 0.7261 | Dev Loss: 0.5668
# Epoch 445 | Train Loss: 0.7253 | Dev Loss: 0.5672
# Epoch 446 | Train Loss: 0.7233 | Dev Loss: 0.5676
# Epoch 447 | Train Loss: 0.7288 | Dev Loss: 0.5680
# Epoch 448 | Train Loss: 0.7244 | Dev Loss: 0.5681
# Epoch 449 | Train Loss: 0.7201 | Dev Loss: 0.5680
# Epoch 450 | Train Loss: 0.7293 | Dev Loss: 0.5683
# Epoch 451 | Train Loss: 0.7234 | Dev Loss: 0.5688
# Epoch 452 | Train Loss: 0.7267 | Dev Loss: 0.5691
# Epoch 453 | Train Loss: 0.7243 | Dev Loss: 0.5693
# Epoch 454 | Train Loss: 0.7291 | Dev Loss: 0.5694
# Epoch 455 | Train Loss: 0.7216 | Dev Loss: 0.5698
# Epoch 456 | Train Loss: 0.7311 | Dev Loss: 0.5700
# Epoch 457 | Train Loss: 0.7250 | Dev Loss: 0.5701
# Epoch 458 | Train Loss: 0.7261 | Dev Loss: 0.5704
# Epoch 459 | Train Loss: 0.7260 | Dev Loss: 0.5705
# Epoch 460 | Train Loss: 0.7194 | Dev Loss: 0.5709
# Epoch 461 | Train Loss: 0.7191 | Dev Loss: 0.5712
# Epoch 462 | Train Loss: 0.7220 | Dev Loss: 0.5716
# Epoch 463 | Train Loss: 0.7206 | Dev Loss: 0.5718
# Epoch 464 | Train Loss: 0.7197 | Dev Loss: 0.5721
# Epoch 465 | Train Loss: 0.7321 | Dev Loss: 0.5726
# Epoch 466 | Train Loss: 0.7277 | Dev Loss: 0.5731
# Epoch 467 | Train Loss: 0.7277 | Dev Loss: 0.5734
# Epoch 468 | Train Loss: 0.7234 | Dev Loss: 0.5735
# Epoch 469 | Train Loss: 0.7155 | Dev Loss: 0.5733
# Epoch 470 | Train Loss: 0.7209 | Dev Loss: 0.5735
# Epoch 471 | Train Loss: 0.7202 | Dev Loss: 0.5737
# Epoch 472 | Train Loss: 0.7188 | Dev Loss: 0.5740
# Epoch 473 | Train Loss: 0.7246 | Dev Loss: 0.5747
# Epoch 474 | Train Loss: 0.7200 | Dev Loss: 0.5750
# Epoch 475 | Train Loss: 0.7228 | Dev Loss: 0.5755
# Epoch 476 | Train Loss: 0.7155 | Dev Loss: 0.5760
# Epoch 477 | Train Loss: 0.7226 | Dev Loss: 0.5759
# Epoch 478 | Train Loss: 0.7201 | Dev Loss: 0.5757
# Epoch 479 | Train Loss: 0.7213 | Dev Loss: 0.5757
# Epoch 480 | Train Loss: 0.7178 | Dev Loss: 0.5763
# Epoch 481 | Train Loss: 0.7196 | Dev Loss: 0.5769
# Epoch 482 | Train Loss: 0.7155 | Dev Loss: 0.5772
# Epoch 483 | Train Loss: 0.7171 | Dev Loss: 0.5774
# Epoch 484 | Train Loss: 0.7229 | Dev Loss: 0.5778
# Epoch 485 | Train Loss: 0.7176 | Dev Loss: 0.5782
# Epoch 486 | Train Loss: 0.7177 | Dev Loss: 0.5788
# Epoch 487 | Train Loss: 0.7127 | Dev Loss: 0.5793
# Epoch 488 | Train Loss: 0.7141 | Dev Loss: 0.5796
# Epoch 489 | Train Loss: 0.7196 | Dev Loss: 0.5800
# Epoch 490 | Train Loss: 0.7113 | Dev Loss: 0.5805
# Epoch 491 | Train Loss: 0.7217 | Dev Loss: 0.5814
# Epoch 492 | Train Loss: 0.7176 | Dev Loss: 0.5817
# Epoch 493 | Train Loss: 0.7204 | Dev Loss: 0.5822
# Epoch 494 | Train Loss: 0.7229 | Dev Loss: 0.5832
# Epoch 495 | Train Loss: 0.7197 | Dev Loss: 0.5841
# Epoch 496 | Train Loss: 0.7200 | Dev Loss: 0.5847
# Epoch 497 | Train Loss: 0.7196 | Dev Loss: 0.5854
# Epoch 498 | Train Loss: 0.7202 | Dev Loss: 0.5861
# Epoch 499 | Train Loss: 0.7203 | Dev Loss: 0.5863
# Epoch 500 | Train Loss: 0.7156 | Dev Loss: 0.5867

# %%
# Final evaluation on dev set ranking
model.load_state_dict(torch.load('best_distmult.pt'))
mrr, hits = evaluate_ranking(model, test_data, num_entities, device,  k_values=(1,3,5))
print(f"Dev Ranking → MRR: {mrr:.4f}, " + ", ".join([f"{k}: {v:.4f}" for k,v in hits.items()]))
# Out:
# Dev Ranking → MRR: 0.3187, Hits@1: 0.2826, Hits@3: 0.3043, Hits@5: 0.3478
# C:\Users\jerry\AppData\Local\Temp\ipykernel_13996\2621427780.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_distmult.pt'))

# %%
  # Final evaluation on dev set ranking
model.load_state_dict(torch.load('best_distmult.pt'))
mrr, hits = evaluate_ranking(model, test_data, num_entities, device, num_neg=100, k_values=(1,3,10))
print(f"Dev Ranking → MRR: {mrr:.4f}, " + ", ".join([f"{k}: {v:.4f}" for k,v in hits.items()]))
# Out:
# Dev Ranking → MRR: 0.3047, Hits@1: 0.2609, Hits@3: 0.3043, Hits@10: 0.3696
# C:\Users\jerry\AppData\Local\Temp\ipykernel_13996\771319534.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_distmult.pt'))
